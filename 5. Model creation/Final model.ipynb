# %%
import pickle
import warnings
warnings.filterwarnings("ignore")

# %%
filename="Random_model.sav"

# %%
loaded_model=pickle.load(open("Random_model.sav",'rb'))

# %%
unitprice_input=float(input("Unit Price:"))
quantity_input=float(input("Quantity:"))
vat_input=float(input("Vat:"))
cogs_input=float(input("Cost of goods sold:"))
gross_input=float(input("Gross Income:"))
# Out:
# Unit Price: 50
# Quantity: 15
# Vat: 120
# Cost of goods sold: 45
# Gross Income: 500

# %%
# Result
Amt_Prediction=loaded_model.predict([[unitprice_input,quantity_input,vat_input,cogs_input,gross_input,]])

# %%
print("Invoice Amount Prediction:",Amt_Prediction)
# Out:
# Invoice Amount Prediction: [639.14886]
